# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import PIL
import pandas as pd 
import os
from skimage.io import imread
from skimage.transform import resize
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import pathlib

# %%
dir = './train/'

# %%
fn = [i for i in os.listdir(dir)]

# %%
len(fn)
# Out:
# 1185

# %%
fn2 =[]

for j in fn :
    fn2.append(j.replace('.png',''))

# %%
fn2
# Out:
# ['1b1q3k-4Qbpp-pp1P1p2-1r3N2-6P1-B6P-5P2-3R2K1',
#  '1B1qkbnr-1b2pp2-3p3p-6p1-2P5-p1N2N2-PP1QPPPP-2KR1B1R',
#  '1B1qr1k1-1b3ppp-pn2p3-3pP3-1p3P2-1P5P-P1P1B1P1-R2Q1RK1',
#  '1b1r1r1k-1p2R1pp-p2PQnp1-2p1N1B1-8-7P-PqP2PP1-4R1K1',
#  '1b1r1rk1-2pq1pp1-p3p1bp-1pPn4-1P1Np2P-PQN5-1B1P1PP1-R3R1K1',
#  '1b1r1rk1-pb3pp1-1p5p-1Bp5-2N4q-4P2P-PPQ3P1-3RR1K1',
#  '1b1r2k1-1p4p1-pr2pn1p-3p4-8-1BP2Q2-PP3PPq-1R2R1K1',
#  '1b1r2k1-pb1r3p-1pq2p2-2p5-P1P5-3p2P1-1P2Q2P-R2RN1K1',
#  '1b1r4-1pkr2pp-p3b3-N1P2p2-PP2p3-5P2-3NK1PP-R1R5',
#  '1b2k2r-1b2qppp-p3pn2-1p6-1Pr5-P1N1PN2-1B2QPPP-3R1RK1',
#  '1b2k3-1p3p2-p3q3-8-1P6-P3PQPP-8-2R3K1',
#  '1B2kb1r-pp2p1pp-4Pn2-8-6P1-P2B4-1P5P-R3K1Nb',
#  '1b2Q3-pbk2p2-1p2p3-1Bp1P1p1-5P2-6P1-P2K2q1-8',
#  '1b2r1k1-4p2p-4N1p1-5p2-5P2-4R1PP-b1r5-4R2K',
#  '1b2r1k1-4rpp1-7p-8-1pQ1P3-2p3P1-P1P2R1K-8',
#  '1b2r2k-1p1n2rp-p1p2q2-P1Pp4-1P5P-4P2Q-5PP1-2R2RK1',
#  '1b2r3-1b3rk1-3q4-pp1p1pp1-2pP4-1PP1PQpP-P2N4-2R1BRK1',
#  '1B3k2-8-4Q3-4N1p1-6P1-8-5PK1-8',
# ...

# %%
data_dir = './Problem03/train/'

# %%
data = []

# %%
labelf = []
for u in fn2:
    for v in u.split('-'):
        labelf.append(v)

# %%
for n in fn :
    img = imread(f'./train/{n}')
    img_pieces = np.split(img, 8, axis=0)
    for k in img_pieces:
        imgr = resize(k, (15, 15))
        data.append(imgr.flatten())

# %%
data = np.asarray(data)
labels = np.asarray(labelf)

# %%
len(data) == len(labels)
# Out:
# True

# %%
# train / test split
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, shuffle=True)

# %%
data
# Out:
# array([[0.12981044, 0.12981044, 0.12981044, ..., 0.39292794, 0.30370447,
#         0.21693787],
#        [0.51820794, 0.43227687, 0.34806174, ..., 0.37780715, 0.31887071,
#         0.26101888],
#        [0.43742859, 0.31500211, 0.19600752, ..., 0.43742744, 0.31500051,
#         0.19600534],
#        ...,
#        [0.43742859, 0.31500211, 0.19600752, ..., 0.43742744, 0.31500051,
#         0.19600534],
#        [0.51820794, 0.43227687, 0.34806174, ..., 0.50973968, 0.42541946,
#         0.34282058],
#        [0.38611613, 0.30330988, 0.22289933, ..., 0.12970872, 0.12970872,
#         0.12970872]])

# %%
len(data)
# Out:
# 9480

# %%
# train classifier
classifier = SVC()

parameters = [{'gamma': [0.01, 0.001, 0.0001], 'C': [1, 10, 100, 1000]}]

grid_search = GridSearchCV(classifier, parameters)

# %%
grid_search.fit(x_train, y_train)
# Out:
# C:\Users\Ali\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# GridSearchCV(estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000],
#                           'gamma': [0.01, 0.001, 0.0001]}])

# %%
best_estimator = grid_search.best_estimator_

y_prediction = best_estimator.predict(x_test)

score = accuracy_score(y_prediction, y_test)

print('{}% of samples were correctly classified'.format(str(score * 100)))
# Out:
# 58.70253164556962% of samples were correctly classified

# %%
y_prediction
# Out:
# array(['1B6', 'P7', '2r3k1', ..., '1B1P1PP1', '6B1', '3P4'], dtype='<U8')

# %%
datat =[]

# %%
for l in range(0,4562):
    img = imread(f'./test/img{l}.png')
    img_pieces = np.split(img, 8, axis=0)
    for k in img_pieces:
        imgr = resize(k, (15, 15))
        datat.append(imgr.flatten())

# %%
len(datat)
# Out:
# 36496

# %%
y = best_estimator.predict(datat)

# %%
len(y)
# Out:
# 36496

# %%
x = list(y)

# %%
y
# Out:
# array(['r5k1', 'pppb3p', '6p1', ..., 'P1Q2p2', '4q3', '8'], dtype='<U8')

# %%
d= []

# %%
while len(x) > 0 :
    s=''
    for i in range(0,8):
        s = s+x[i]+'-'
    x.pop(0)
    x.pop(0)
    x.pop(0)
    x.pop(0)
    x.pop(0)
    x.pop(0)
    x.pop(0)
    x.pop(0)
    d.append(s)
    print(len(y))
# Out:
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# 36496
# ...

# %%
x
# Out:
# []

# %%
d
# Out:
# ['r5k1-pppb3p-6p1-8-3P1q2-7P-PP3PP1-2R2RK1-',
#  '8-5ppp-p6p-P7-3PB3-4P3-3N1P2-8-',
#  '5rk1-7p-6p1-p7-P2p4-1bBP4-1RPrP3-8-',
#  '2r5-4qppp-3pp2p-3pN3-1P1PpPb1-4P3-1P4PP-5RK1-',
#  'rQ2kb1r-ppp1pppp-2n5-1N6-P1pB4-4P1PP-PP3PPq-R1BR4-',
#  '8-pp5p-6q1-4p3-7B-3P2P1-PP1p2N1-7K-',
#  'r1b1k2r-pp2pppp-2p5-4P3-6n1-8-PPP2PPP-RNBQ1B1R-',
#  '1b6-8-np6-8-P7-2NBP3-7p-3NR3-',
#  'r5k1-2p3pp-1p3p2-p2p4-3Pp3-3QPB2-P2K2q1-6RK-',
#  '8-8-8-pbqp2p1-5p2-P7-3K4-8-',
#  'r4rk1-ppp2ppp-2n1p3-8-3P4-3P1Q2-PPPQ1PPP-2K3RR-',
#  'rR3b1k-pbq1n1p1-2n4p-5p2-4p3-2P2N2-PP1N1PPP-R2QKB1R-',
#  'rnbqk2r-pp3ppp-2pb1n2-6b1-2PPPP2-2P2R2-PP4PP-R1B1Q1K1-',
#  '6k1-p1p3pp-4p3-5p2-PP2p3-2p5-2r5-R1B1r3-',
#  '2r3k1-5ppp-4p1p1-6B1-p2P4-5N2-2P2P1P-5BK1-',
#  'rR3b1k-pppq4-2kp1p2-4n1p1-2B1P3-6Pp-PP5K-R1BQ1R2-',
#  'r4rk1-p4ppp-2p5-4p3-3p4-1P1p1P2-q5PP-7R-',
#  '1r4k1-pB4bp-2p5-2N1p3-2n2pP1-3P1P2-2P3PP-3Q1RK1-',
#  '8-R7-7p-8-P7-4KP2-1Pr5-8-',
#  '6k1-5ppp-4p3-1P1bP3-3P2P1-2P1BP2-4K3-7R-',
# ...

# %%
o = []
for u in d :
    u = u[:-1]
    o.append(u)

# %%
o
# Out:
# ['r5k1-pppb3p-6p1-8-3P1q2-7P-PP3PP1-2R2RK1',
#  '8-5ppp-p6p-P7-3PB3-4P3-3N1P2-8',
#  '5rk1-7p-6p1-p7-P2p4-1bBP4-1RPrP3-8',
#  '2r5-4qppp-3pp2p-3pN3-1P1PpPb1-4P3-1P4PP-5RK1',
#  'rQ2kb1r-ppp1pppp-2n5-1N6-P1pB4-4P1PP-PP3PPq-R1BR4',
#  '8-pp5p-6q1-4p3-7B-3P2P1-PP1p2N1-7K',
#  'r1b1k2r-pp2pppp-2p5-4P3-6n1-8-PPP2PPP-RNBQ1B1R',
#  '1b6-8-np6-8-P7-2NBP3-7p-3NR3',
#  'r5k1-2p3pp-1p3p2-p2p4-3Pp3-3QPB2-P2K2q1-6RK',
#  '8-8-8-pbqp2p1-5p2-P7-3K4-8',
#  'r4rk1-ppp2ppp-2n1p3-8-3P4-3P1Q2-PPPQ1PPP-2K3RR',
#  'rR3b1k-pbq1n1p1-2n4p-5p2-4p3-2P2N2-PP1N1PPP-R2QKB1R',
#  'rnbqk2r-pp3ppp-2pb1n2-6b1-2PPPP2-2P2R2-PP4PP-R1B1Q1K1',
#  '6k1-p1p3pp-4p3-5p2-PP2p3-2p5-2r5-R1B1r3',
#  '2r3k1-5ppp-4p1p1-6B1-p2P4-5N2-2P2P1P-5BK1',
#  'rR3b1k-pppq4-2kp1p2-4n1p1-2B1P3-6Pp-PP5K-R1BQ1R2',
#  'r4rk1-p4ppp-2p5-4p3-3p4-1P1p1P2-q5PP-7R',
#  '1r4k1-pB4bp-2p5-2N1p3-2n2pP1-3P1P2-2P3PP-3Q1RK1',
#  '8-R7-7p-8-P7-4KP2-1Pr5-8',
#  '6k1-5ppp-4p3-1P1bP3-3P2P1-2P1BP2-4K3-7R',
#  'r7-n6k-p2p2P1-1pp2p2-1pP1P3-1P3P2-P3KP1P-7R',
# ...

# %%
images = []

for z in range(0,4562):
    images.append(f'img{z}')

# %%
df = pd.DataFrame({'image' : images , 'label' : o})

# %%
df
# Out:
#         image                                              label
# 0        img0           r5k1-pppb3p-6p1-8-3P1q2-7P-PP3PP1-2R2RK1
# 1        img1                     8-5ppp-p6p-P7-3PB3-4P3-3N1P2-8
# 2        img2                 5rk1-7p-6p1-p7-P2p4-1bBP4-1RPrP3-8
# 3        img3       2r5-4qppp-3pp2p-3pN3-1P1PpPb1-4P3-1P4PP-5RK1
# 4        img4  rQ2kb1r-ppp1pppp-2n5-1N6-P1pB4-4P1PP-PP3PPq-R1BR4
# ...       ...                                                ...
# 4557  img4557    1r5r-5p1p-1p2pn2-3pr1p1-1R6-2P2P1N-1PQ2PP1-R4R2
# 4558  img4558       2kr4-1pp2p1p-p3bQ2-8-b1pPP3-P7-P3PPPP-2R2RK1
# 4559  img4559             8-3p2p1-p2pp1p1-5p1p-pP4p1-6P1-P4PK1-8
# 4560  img4560  r2bkr2-ppp3pp-3p4-2b5-2B1PBn1-2N2Q2-PPPP1PPP-R...
# 4561  img4561                         8-8-5p2-8-2b5-P1Q2p2-4q3-8
#
# [4562 rows x 2 columns]

# %%
df.to_csv('predictions.csv' , index=False)
